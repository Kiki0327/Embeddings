# %% [markdown]
# ## Proyecto de busqueda

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from ast import literal_eval

# %%
# Global vars
path = 'G:/Mi unidad/Cursos/Platzi/Embeddings/'

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ## Cargando base

# %%
df = pd.read_csv(path+'data/25k-imdb-movie-dataset.csv')
print(df.shape)

# %%
df.sample(3)

# %%
df.isna().sum()/df.shape[0]

# %% [markdown]
# --------------------------------

# %% [markdown]
# ## Limpieza de datos

# %%
def concatenar_lista(lista):
    lista = literal_eval(lista)
    return ' '.join(lista)

# %%
def string_to_list(lista):
    lista = literal_eval(lista)
    return lista

# %%
df = df.fillna(' ')
df['Keywords'] = df['Plot Kyeword'].apply(concatenar_lista)
df['Stars'] = df['Top 5 Casts'].apply(concatenar_lista)
df['Generes'] = df['Generes'].apply(string_to_list)
df['Rating'] = pd.to_numeric(df['Rating'], errors="coerce").fillna(0).astype("float")

# %%
unique_generes = df['Generes'].explode().unique()
unique_generes

# %%
df.drop(['Plot Kyeword','Top 5 Casts'],axis=1, inplace=True)

# %%
df['text'] = df.apply(lambda x : str(x['Overview'])+' '+x['Keywords']+' '+x['Stars'], axis=1)

# %%
df.sample(3)

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ## Embeddings model

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
df['length_text'] = df['text'].apply(lambda x: len(x))
df['length_text'].describe()

# %%
embeddings = model.encode(df['text'],show_progress_bar=True)

# %%
df['embeddings'] = embeddings.tolist()
df['ids'] = df.index
df['ids'] = df['ids'].astype('str')

# %%
df.sample(3)

# %%
# Guardar la base para no volver a crear los embeddings
df.to_csv(path+'data/25k-imdb-movie-dataset-new.csv', sep='|', index=False)

# %%
df = pd.read_csv(path+'data/25k-imdb-movie-dataset-new.csv', sep='|')
print(df.shape)
# Out:
# (24402, 16)

# %%
df['movie title'].unique().tolist()
# Out:
# ['Top Gun: Maverick',
#  'Jurassic World Dominion',
#  'Top Gun',
#  'Lightyear',
#  'Spiderhead',
#  'Everything Everywhere All at Once',
#  'Interceptor',
#  'Black Adam',
#  'The Northman',
#  'Thor: Love and Thunder',
#  'Fantastic Beasts: The Secrets of Dumbledore',
#  'The Unbearable Weight of Massive Talent',
#  'Jurassic Park',
#  'Doctor Strange in the Multiverse of Madness',
#  'No Time to Die',
#  'The Batman',
#  'Bullet Train',
#  'Jurassic World',
#  'Jurassic World: Fallen Kingdom',
#  'Vikram',
#  'Morbius',
#  'The Lost City',
#  'Spider-Man: No Way Home',
#  'Last Seen Alive',
#  'Sonic the Hedgehog 2',
#  'Uncharted',
#  'Prey',
#  'Ambulance',
#  'The Lost World: Jurassic Park',
#  'Dune',
#  'Jurassic Park III',
#  'Star Wars',
#  'The Gray Man',
#  'Avengers: Endgame',
#  'The Lady of Heaven',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Eternals',
#  'Free Guy',
#  'The Matrix Resurrections',
#  'Mission: Impossible',
#  'Memory',
#  'Star Wars: Episode I - The Phantom Menace',
#  'The Adam Project',
#  "The King's Man",
#  'The Dark Knight',
#  'Aquaman',
#  'The Gentlemen',
#  'Mission: Impossible - Fallout',
#  'Samrat Prithviraj',
#  'Blade Runner 2049',
#  'Inception',
#  'Moonfall',
#  'Avatar: The Way of Water',
#  'Major',
#  'Star Wars: Episode III - Revenge of the Sith',
#  'Mission: Impossible - Dead Reckoning - Part One',
#  'The Contractor',
#  'Road House',
#  'Mission: Impossible - Ghost Protocol',
#  'Star Wars: Episode IX - The Rise of Skywalker',
#  'Venom: Let There Be Carnage',
#  'Heat',
#  'Nobody',
#  'Avatar',
#  'The Suicide Squad',
#  'Avengers: Infinity War',
#  'Thor: Ragnarok',
#  'Spree',
#  'Guardians of the Galaxy',
#  'The Last Duel',
#  'Mission: Impossible II',
#  'Wrath of Man',
#  'Pirates of the Caribbean: Dead Men Tell No Tales',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Sonic the Hedgehog',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Aquaman and the Lost Kingdom',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'The Amazing Spider-Man',
#  'Spectre',
#  'The Hunger Games: The Ballad of Songbirds and Snakes',
#  'Watchmen',
#  'Tenet',
#  'Shang-Chi and the Legend of the Ten Rings',
#  'Ghostbusters',
#  'The Hunger Games',
#  'The Mortal Instruments: City of Bones',
#  'Black Widow',
#  'Willow',
#  'Independence Day',
#  'Mission: Impossible - Rogue Nation',
#  'Casino Royale',
#  'The Fifth Element',
#  'Deadpool',
#  'Doctor Strange',
#  'Enola Holmes',
#  'Divergent',
#  'The Accountant',
#  'Spider-Man',
#  'Operation Fortune: Ruse de guerre',
#  "Zack Snyder's Justice League",
#  'Die Hard',
#  'Mission: Impossible III',
#  'Blade Runner',
#  'Mad Max: Fury Road',
#  'K.G.F: Chapter 2',
#  'White Elephant',
#  'Blacklight',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'Spider-Man: Homecoming',
#  'Resident Evil: Welcome to Raccoon City',
#  'Captain Marvel',
#  'Aliens',
#  '1917',
#  'Star Wars: Episode VII - The Force Awakens',
#  'The Matrix',
#  'The Flash',
#  'Gladiator',
#  'Kingsman: The Secret Service',
#  'Predator',
#  'Red Notice',
#  'Spider-Man: Into the Spider-Verse',
#  'The Mummy',
#  'Batman Begins',
#  'Star Wars: Episode VIII - The Last Jedi',
#  '21 Bridges',
#  'Apocalypto',
#  'Jack Reacher',
#  'Drive',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Oblivion',
#  'The Hunt',
#  '300',
#  'Suicide Squad',
#  'The Dark Knight Rises',
#  'Starship Troopers',
#  'The Old Guard',
#  'The Lord of the Rings: The Return of the King',
#  "Pirates of the Caribbean: At World's End",
#  'Black Panther',
#  'Edge of Tomorrow',
#  'Dunkirk',
#  'The Marvels',
#  'Baywatch',
#  'Waterworld',
#  'John Wick',
#  'Twister',
#  'Black Hawk Down',
#  'Deadpool 2',
#  'Thor',
#  'Skyfall',
#  'Iron Man',
#  'Oldboy',
#  'The Man from Toronto',
#  'Black Panther: Wakanda Forever',
#  'The Informer',
#  'Sicario',
#  'Solo: A Star Wars Story',
#  'Batman Forever',
#  'Jumanji: The Next Level',
#  'The Avengers',
#  'The Terminator',
#  'John Wick: Chapter 4',
#  'Strange World',
#  'Fury',
#  'Ford v Ferrari',
#  'Spider-Man 3',
#  'The Tomorrow War',
#  'Public Enemies',
#  'Venom',
#  'Brahmastra Part One: Shiva',
#  'War of the Worlds',
#  'Fantastic Four',
#  'Captain America: The First Avenger',
#  'Terminator 2: Judgment Day',
#  'Tropic Thunder',
#  'Star Trek',
#  'The Revenant',
#  'Godzilla vs. Kong',
#  'Guardians of the Galaxy Vol. 3',
#  'Dune: Part Two',
#  'Collateral',
#  'The 355',
#  'Baby Driver',
#  'Only the Brave',
#  '10,000 BC',
#  '6 Underground',
#  'Paws of Fury: The Legend of Hank',
#  'The Amazing Spider-Man 2',
#  'Jungle Cruise',
#  'Infinite',
#  'The Fast and the Furious',
#  'Guardians of the Galaxy Vol. 2',
#  'Fast X',
#  'Justice League',
#  'Batman',
#  'DC League of Super-Pets',
#  'Spider-Man: Across the Spider-Verse',
#  'Speed',
#  'Indiana Jones and the Last Crusade',
#  'The Last Samurai',
#  'Transformers',
#  'Logan',
#  'Armageddon',
#  'Spider-Man: Far from Home',
#  'Ready or Not',
#  'The Crow',
#  'Kill Bill: Vol. 1',
#  'Minority Report',
#  'Ready Player One',
#  'Hell or High Water',
#  'Man of Steel',
#  'The Lord of the Rings: The Two Towers',
#  'The Harder They Fall',
#  'Kick-Ass',
#  'Shazam!',
#  'Jumanji: Welcome to the Jungle',
#  'The Incredibles',
#  'Con Air',
#  'Wonder Woman 1984',
#  'Predestination',
#  'Indiana Jones and the Temple of Doom',
#  'Avengers: Age of Ultron',
#  'The School for Good and Evil',
#  'The Fighter',
#  'Kingsman: The Golden Circle',
#  'Wonder Woman',
#  'Knowing',
#  'Mortal Kombat',
#  'Zombieland',
#  'El Camino: A Breaking Bad Movie',
#  'The Magnificent Seven',
#  'The Other Guys',
#  'Transformers: Rise of the Beasts',
#  'Hellboy',
#  'The Maze Runner',
#  'Raya and the Last Dragon',
#  'Men in Black',
#  'Shazam! Fury of the Gods',
#  'Midnight in the Switchgrass',
#  'Army of the Dead',
#  "Hitman's Wife's Bodyguard",
#  'Scott Pilgrim vs. the World',
#  'Captain America: Civil War',
#  "The Hitman's Bodyguard",
#  'The Predator',
#  'Quantum of Solace',
#  'Days of Thunder',
#  'Knight and Day',
#  'Taken',
#  'The Mask',
#  'The Fugitive',
#  'Thor: The Dark World',
#  'Gods of Egypt',
#  'Batgirl',
#  'Rush',
#  'Extraction',
#  'The Rock',
#  'World War Z',
#  'Battleship',
#  'K.G.F: Chapter 1',
#  'Attack',
#  'Batman & Robin',
#  'The Tourist',
#  'Alita: Battle Angel',
#  'Batman Returns',
#  'In Time',
#  'The Equalizer',
#  'Argylle',
#  'V for Vendetta',
#  'The Siege of Robin Hood',
#  'The Bourne Identity',
#  'Point Break',
#  'Power Rangers',
#  'Sucker Punch',
#  'X-Men',
#  "Don't Breathe 2",
#  'Army of Thieves',
#  'Superman',
#  'The Incredible Hulk',
#  'Highlander',
#  'Kaithi',
#  'Kingdom of Heaven',
#  'Greenland',
#  'The Legend of Tarzan',
#  'The Meg',
#  'Game Night',
#  'X-Men: Apocalypse',
#  'King Arthur: Legend of the Sword',
#  'Den of Thieves',
#  'Face/Off',
#  'Murder Mystery',
#  'Snake Eyes',
#  'From Dusk Till Dawn',
#  'The Hunger Games: Catching Fire',
#  "Ocean's Eight",
#  'RED',
#  'The Karate Kid',
#  'GoldenEye',
#  'How to Train Your Dragon',
#  'Total Recall',
#  'Pineapple Express',
#  'Warrior',
#  'Wolf Hound',
#  'Jack Reacher: Never Go Back',
#  'Harry Potter and the Order of the Phoenix',
#  'Hot Fuzz',
#  'Allied',
#  'American Made',
#  'First Blood',
#  'The New Mutants',
#  'Eraser',
#  'Unlocked',
#  'The Spy Who Never Dies',
#  'Training Day',
#  'Love and Monsters',
#  'The Patriot',
#  'Rango',
#  'Chaos Walking',
#  'Wanted',
#  'Rush Hour',
#  'Endangered Species',
#  'Spider-Man 2',
#  'Transformers: The Last Knight',
#  'Midnight Run',
#  'Ip Man: The Awakening',
#  'Overlord',
#  'Dr. No',
#  'Ava',
#  'Conan the Barbarian',
#  'Tomb Raider',
#  'Old Henry',
#  'Harry Potter and the Half-Blood Prince',
#  "Logan's Run",
#  'Captain America: The Winter Soldier',
#  'Hard to Kill',
#  'Open Range',
#  'The Rocketeer',
#  'The Nice Guys',
#  'Pearl Harbor',
#  'Snowpiercer',
#  'Kung Fu Panda',
#  'Looper',
#  'John Wick: Chapter 3 - Parabellum',
#  'Batman v Superman: Dawn of Justice',
#  'Inferno',
#  'Planet of the Apes',
#  'King Kong',
#  'Masters of the Universe',
#  'Smokey and the Bandit',
#  'Miami Vice',
#  'Polar',
#  'Lock, Stock and Two Smoking Barrels',
#  'Jumper',
#  'Mulan',
#  'Blade',
#  '2012',
#  'Gold',
#  'The Day After Tomorrow',
#  'The Warriors',
#  '13 Hours',
#  'The Protégé',
#  'Teenage Mutant Ninja Turtles',
#  'Mr. & Mrs. Smith',
#  'Iron Man 2',
#  'Constantine',
#  'Pacific Rim',
#  'Incredibles 2',
#  'Ant-Man',
#  'G.I. Joe: The Rise of Cobra',
#  'Big Hero 6',
#  'Man on Fire',
#  'Terminator: Dark Fate',
#  'X-Men: Days of Future Past',
#  'Tag',
#  'Robin Hood',
#  'Central Intelligence',
#  'Death Proof',
#  'Shooter',
#  'Never Back Down',
#  'Angel Has Fallen',
#  'The Princess',
#  'Live Free or Die Hard',
#  'Dredd',
#  "Charlie's Angels",
#  'Hitman: Agent 47',
#  'The Fast and the Furious: Tokyo Drift',
#  'Hitman',
#  'Triple Frontier',
#  '21 Jump Street',
#  'Warcraft',
#  'Falling Down',
#  'District 9',
#  'RoboCop',
#  'The Mummy Returns',
#  'Beverly Hills Cop',
#  'Pokémon: Detective Pikachu',
#  'Star Trek Beyond',
#  'Copshop',
#  'Children of Men',
#  'The Man from U.N.C.L.E.',
#  'American Sniper',
#  'Eraser: Reborn',
#  'Rambo: Last Blood',
#  'Resident Evil',
#  'Mandy',
#  'Tomorrow Never Dies',
#  'Midway',
#  'Red Sparrow',
#  'Revenge',
#  'We Can Be Heroes',
#  'Samaritan',
#  'Underwater',
#  'Fast & Furious',
#  '3:10 to Yuma',
#  'Mad Max',
#  'Over the Top',
#  'The Losers',
#  'Hot Shots!',
#  'A History of Violence',
#  'Gunpowder Milkshake',
#  'The Fate of the Furious',
#  'Logan Lucky',
#  'Red Dawn',
#  'Vendetta',
#  'Hulk',
#  'Ant-Man and the Wasp: Quantumania',
#  'Stargate',
#  'The Last of the Mohicans',
#  'Dick Tracy',
#  'U.S. Marshals',
#  'Godzilla: King of the Monsters',
#  'In the Heart of the Sea',
#  'Allegiant',
#  'Deep Impact',
#  'Angels & Demons',
#  'The Blues Brothers',
#  'The Last Airbender',
#  'The Quick and the Dead',
#  'Sherlock Holmes',
#  'The Book of Eli',
#  'Sicario: Day of the Soldado',
#  'Kong: Skull Island',
#  'Forsaken',
#  'Fast Five',
#  'Snow White and the Huntsman',
#  'Star Trek Into Darkness',
#  'Bumblebee',
#  'Enola Holmes 2',
#  'The Roundup',
#  'Rocketry: The Nambi Effect',
#  'Law Abiding Citizen',
#  'Kate',
#  'Deep Blue Sea',
#  'John Wick: Chapter 2',
#  'They Live',
#  'The Saint',
#  'Predators',
#  'The Guest',
#  'The Vault',
#  'Deadpool 3',
#  'Pixels',
#  'Van Helsing',
#  'The Silencing',
#  'Small Soldiers',
#  'Die Hard 2',
#  'The Last Castle',
#  'National Treasure',
#  'Geostorm',
#  'Fast & Furious Presents: Hobbs & Shaw',
#  'Independence Day: Resurgence',
#  'Ant-Man and the Wasp',
#  'Napoleon',
#  'Green Lantern',
#  'Big Trouble in Little China',
#  'Hotel Mumbai',
#  'X-Men Origins: Wolverine',
#  'Anek',
#  'Double Threat',
#  'Pain & Gain',
#  'I Am Legend',
#  'Greyhound',
#  'Lucy',
#  'The Forever Purge',
#  'Super 8',
#  "Willy's Wonderland",
#  'The Twilight Saga: Eclipse',
#  'Hunter Killer',
#  'Olympus Has Fallen',
#  'Bad Boys for Life',
#  'Romancing the Stone',
#  'Tomorrowland',
#  'No Way Out',
#  'Sky High',
#  'Ghost Rider',
#  'Bad Boys',
#  'Deja Vu',
#  'Cloverfield',
#  'Men in Black 3',
#  'Daybreakers',
#  'Corrective Measures',
#  'Underworld',
#  'The Colony',
#  'Drive Angry',
#  'Ghostbusters II',
#  'The Outpost',
#  'Natural Born Killers',
#  'Hollow Man',
#  "Dante's Peak",
#  'John Carter',
#  'The Matrix Reloaded',
#  'A View to a Kill',
#  'The Hunt for Red October',
#  'Spiral',
#  'Alien³',
#  'Extraction 2',
#  'Transcendence',
#  'Goldfinger',
#  'The Transporter',
#  'Rambo: First Blood Part II',
#  'The Shallows',
#  'Robin Hood: Prince of Thieves',
#  'Adrift',
#  '2 Fast 2 Furious',
#  'Escape from New York',
#  'Anna',
#  'Clean',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Bullitt',
#  'The Finest Hours',
#  'Day Shift',
#  'Predator 2',
#  'I Saw the Devil',
#  'Spy Kids',
#  'Godzilla',
#  'The Lego Movie',
#  'Kill Bill: Vol. 2',
#  'The Longest Day',
#  'The World Is Not Enough',
#  'The Count of Monte Cristo',
#  'Atomic Blonde',
#  'Lone Survivor',
#  'A Day to Die',
#  'Atlantis: The Lost Empire',
#  'Serenity',
#  'Dawn of the Dead',
#  'Freddy vs. Jason',
#  'Dirty Harry',
#  'Terminator Genisys',
#  'Commando',
#  'Gone in 60 Seconds',
#  'Last Action Hero',
#  'Borderlands',
#  'The Boondock Saints',
#  'Kick-Ass 2',
#  'Scouts Guide to the Zombie Apocalypse',
#  'Upgrade',
#  'North by Northwest',
#  '300: Rise of an Empire',
#  'Superman III',
#  'X-Men: The Last Stand',
#  'Anaconda',
#  'Mortal Engines',
#  'Kraven the Hunter',
#  'Young Guns',
#  '13 Minutes',
#  'Dungeons & Dragons',
#  'Live and Let Die',
#  'Valerian and the City of a Thousand Planets',
#  'Kindergarten Cop',
#  'Unhinged',
#  'Unbroken',
#  'Gravity',
#  'From Russia with Love',
#  'The Hunger Games: Mockingjay - Part 2',
#  'Reign of Fire',
#  'True Lies',
#  'Escape Room',
#  'The Running Man',
#  "A Knight's Tale",
#  'Those Who Wish Me Dead',
#  'SAS: Red Notice',
#  'Pacific Rim: Uprising',
#  'Barb Wire',
#  'Escape Room: Tournament of Champions',
#  'Peter Pan & Wendy',
#  'Carriers',
#  'Desperado',
#  'The Guardian',
#  'Air Force One',
#  'Speed 2: Cruise Control',
#  'Push',
#  'A Good Day to Die Hard',
#  'Howard the Duck',
#  'Licence to Kill',
#  'Pompeii',
#  'The Spy Who Loved Me',
#  'Now You See Me 2',
#  'The Punisher',
#  'The Cannonball Run',
#  'Riddick',
#  'Eragon',
#  'Monster Hunter',
#  'Die Another Day',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'Thunderball',
#  'Transformers: Age of Extinction',
#  'Layer Cake',
#  'Kung Fu Panda 3',
#  'Clash of the Titans',
#  'Panama',
#  'Alphas',
#  'Sweet Girl',
#  'Men in Black: International',
#  'Firestarter',
#  'The Man with the Golden Gun',
#  'There Are No Saints',
#  'The Iron Giant',
#  'G.I. Joe: Retaliation',
#  'Men in Black II',
#  'The Wild Bunch',
#  'Blade: Trinity',
#  'San Andreas',
#  'Maverick',
#  'Zombieland: Double Tap',
#  'Ip Man',
#  'The Island',
#  'Bloodsport',
#  "On Her Majesty's Secret Service",
#  'How to Train Your Dragon: The Hidden World',
#  'For Your Eyes Only',
#  'The Lone Ranger',
#  'Rise of the Planet of the Apes',
#  'Lethal Weapon',
#  'Hercules',
#  'Austin Powers in Goldmember',
#  'The Chronicles of Riddick',
#  'Sin City: A Dame to Kill For',
#  'We Were Soldiers',
#  'Alexander',
#  'Austin Powers: The Spy Who Shagged Me',
#  'Congo',
#  'Everest',
#  'The 5th Wave',
#  'The Lego Batman Movie',
#  'Rogue',
#  'War for the Planet of the Apes',
#  'RocknRolla',
#  'Jason Bourne',
#  'White House Down',
#  'Terminator Salvation',
#  'Mortdecai',
#  'Megamind',
#  'Homefront',
#  'Maze Runner: The Death Cure',
#  'The Equalizer 2',
#  '12 Strong',
#  'Elysium',
#  'Havoc',
#  'The Expendables 3',
#  'Dawn of the Planet of the Apes',
#  'Kung Fu Panda 2',
#  '47 Ronin',
#  'Ghosted',
#  'Wicked',
#  'Once Upon a Time in Mexico',
#  "Smokin' Aces",
#  'Hansel & Gretel: Witch Hunters',
#  'The Hunger Games: Mockingjay - Part 1',
#  'Rambo',
#  'Demolition Man',
#  'Flash Gordon',
#  '48 Hrs.',
#  'The Living Daylights',
#  'Master and Commander: The Far Side of the World',
#  'Source Code',
#  'Nikamma',
#  'Lifeforce',
#  'The Negotiator',
#  'Spy',
#  'Sherlock Holmes 3',
#  'Transformers: Revenge of the Fallen',
#  'Master',
#  'The Bourne Supremacy',
#  'Diamonds Are Forever',
#  'Outlaw King',
#  '28 Weeks Later',
#  'Immortals',
#  "The King's Daughter",
#  'Superman Returns',
#  'Daredevil',
#  'Transformers: Dark of the Moon',
#  'Rampage',
#  'Thunder Force',
#  'King Arthur',
#  'The Italian Job',
#  'The Wolverine',
#  'Fallen',
#  'Blue Beetle',
#  'Noah',
#  "The Huntsman: Winter's War",
#  'The Ridiculous 6',
#  'The Dirty Dozen',
#  'Westworld',
#  'Cloak & Dagger',
#  'My Spy',
#  'Enemy of the State',
#  'Bad Boys II',
#  'Without Remorse',
#  'WarGames',
#  'Thar',
#  'The Expendables',
#  'Exodus: Gods and Kings',
#  'The Bad Batch',
#  'Pride and Prejudice and Zombies',
#  'How to Train Your Dragon 2',
#  "Fool's Gold",
#  'Bright',
#  'Octopussy',
#  'Terminator 3: Rise of the Machines',
#  'Bloodshot',
#  'Non-Stop',
#  'Species',
#  'The Mask of Zorro',
#  'Furiosa',
#  'Okja',
#  'Moonraker',
#  "It's a Mad Mad Mad Mad World",
#  'The A-Team',
#  'Akira',
#  'I, Robot',
#  'Gamer',
#  'Batman v Superman: Dawn of Justice Ultimate Edition',
#  'Blade II',
#  'Real Steel',
#  'Chronicle',
#  'Spenser Confidential',
#  'Friday Night Lights',
#  'Blood Red Sky',
#  'The Matrix Revolutions',
#  'Death Wish',
#  'The Chronicles of Narnia: Prince Caspian',
#  'First Kill',
#  'Snakes on a Plane',
#  'Sherlock Holmes: A Game of Shadows',
#  'Deliver Us from Evil',
#  'Black Site',
#  'What Happened to Monday',
#  'News of the World',
#  'London Has Fallen',
#  "Ender's Game",
#  'Planet Terror',
#  'Mighty Morphin Power Rangers: The Movie',
#  'We Die Young',
#  'Equilibrium',
#  'Under Siege',
#  'Doom',
#  'Rush Hour 2',
#  'The Covenant',
#  'Pitch Black',
#  'Wild Hogs',
#  'Blowback',
#  'The Man in the Iron Mask',
#  'Sonic the Hedgehog 3',
#  'Jolt',
#  'Nerve',
#  'Maze Runner: The Scorch Trials',
#  'Sarkaru Vaari Paata',
#  'The Last Man',
#  'Guns Akimbo',
#  'Walking Tall',
#  'Death Race',
#  'Machete Kills',
#  "You Don't Mess with the Zohan",
#  'End of Watch',
#  'Project Power',
#  'Dhaakad',
#  'The Old Guard 2',
#  'The Three Musketeers',
#  'Prince of Persia: The Sands of Time',
#  'Krull',
#  'You Only Live Twice',
#  '9',
#  'The Lord of the Rings: The War of the Rohirrim',
#  'WarHunt',
#  'Captain Phillips',
#  'Bonnie and Clyde',
#  "Assassin's Creed",
#  'Om - The Battle Within',
#  'The Bodyguard',
#  'Resident Evil: Apocalypse',
#  'xXx: Return of Xander Cage',
#  'Zoolander 2',
#  'Crank',
#  'Munich',
#  'Safe House',
#  "The World's End",
#  'Creed',
#  'Miss Congeniality',
#  'The League of Extraordinary Gentlemen',
#  'I Am Number Four',
#  'Into the Blue',
#  'Beowulf',
#  'Savages',
#  'Street Fighter',
#  'Out of the Furnace',
#  'Southpaw',
#  'Ghost in the Shell',
#  'Takers',
#  'Prisoners of the Ghostland',
#  'Poseidon',
#  'The Scorpion King',
#  'The Hyperions',
#  'Madame Web',
#  '22 Jump Street',
#  'Entrapment',
#  'Superhero Movie',
#  'Assassination Nation',
#  'Four Brothers',
#  'Jupiter Ascending',
#  'The Bourne Legacy',
#  'George of the Jungle',
#  'Night Teeth',
#  'Conan the Destroyer',
#  '30 Days of Night',
#  'Chappie',
#  'One Shot',
#  '3 Days to Kill',
#  'The Adventures of Sharkboy and Lavagirl 3-D',
#  'The Jackal',
#  'Never Say Never Again',
#  'Lara Croft: Tomb Raider',
#  'In the Line of Fire',
#  'The Interview',
#  'Night Hunter',
#  'Enemy at the Gates',
#  '3 Ninjas',
#  'Crocodile Dundee',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'The Call',
#  'Journey 2: The Mysterious Island',
#  '2 Guns',
#  'The Last Witch Hunter',
#  'The Life Aquatic with Steve Zissou',
#  'Star Trek II: The Wrath of Khan',
#  'Star Wars: The Clone Wars',
#  'Gangster Squad',
#  'Baahubali 2: The Conclusion',
#  'Resident Evil: The Final Chapter',
#  'The 13th Warrior',
#  'Revolver',
#  'Speed Racer',
#  'The Do-Over',
#  'The Woman King',
#  'The Time Machine',
#  'A Walk Among the Tombstones',
#  'Jay and Silent Bob Reboot',
#  'Journey to the Center of the Earth',
#  "The Sorcerer's Apprentice",
#  'Rush Hour 3',
#  'The Bourne Ultimatum',
#  'Rambo III',
#  'Bronson',
#  'Top Gunner: Danger Zone',
#  'The Cloverfield Paradox',
#  'Agent Game',
#  'Hot Shots! Part Deux',
#  'Beverly Hills Cop II',
#  'The Postman',
#  'Zathura: A Space Adventure',
#  'Cliffhanger',
#  'Tank Girl',
#  'Iron Eagle',
#  'Body of Lies',
#  'Body Cam',
#  'Mad Max Beyond Thunderdome',
#  'The VelociPastor',
#  'Team America: World Police',
#  'TRON',
#  'Deepwater Horizon',
#  'Dora and the Lost City of Gold',
#  'S.W.A.T.',
#  'The Dark Tower',
#  'Troll',
#  'Jungle',
#  'Bubble',
#  'Medieval',
#  'Dragonball Evolution',
#  'R.I.P.D.',
#  'Hard Target',
#  'Grindhouse',
#  'Pandorum',
#  'Eagle Eye',
#  'Injustice',
#  'The Last Starfighter',
#  'The Trip',
#  'Legion',
#  "The Girl in the Spider's Web",
#  'Spawn',
#  'Live Die Repeat and Repeat',
#  "Mackenna's Gold",
#  'The Heat',
#  'Get Smart',
#  'Taken 3',
#  'Disturbing the Peace',
#  'Salt',
#  'Street Kings',
#  'Land of the Lost',
#  'Ride Along',
#  'Devotion',
#  'Heist',
#  "Cirque du Freak: The Vampire's Assistant",
#  'Maximum Overdrive',
#  'Shadow in the Cloud',
#  'Ben-Hur',
#  'Dracula Untold',
#  'The Foreigner',
#  'Beast',
#  'Next',
#  'Unstoppable',
#  'Heropanti 2',
#  'Tears of the Sun',
#  'The Adventures of Tintin',
#  'Against All Odds',
#  'Vikram Vedha',
#  'Rise of the Guardians',
#  'Buffy the Vampire Slayer',
#  'Executive Decision',
#  'The French Connection',
#  'Mile 22',
#  '3 from Hell',
#  'Pushpa: The Rise - Part 1',
#  'Red One',
#  'Silverton Siege',
#  'xXx',
#  'The Rundown',
#  'American Assassin',
#  'The Omega Man',
#  'Dangerous',
#  'Escape Plan',
#  'Superman II',
#  'Babylon A.D.',
#  'The Getaway',
#  'Super',
#  'Murder Mystery 2',
#  'G.I. Jane',
#  'Vampire Academy',
#  'The Perfect Storm',
#  'Spy Game',
#  'Ghost Rider: Spirit of Vengeance',
#  'A Most Violent Year',
#  'Black Rain',
#  'The Expendables 2',
#  'Spy Kids 3: Game Over',
#  'Hold the Dark',
#  'Deathstalker',
#  'Rat Race',
#  'Machete',
#  'The Net',
#  'The Guns of Navarone',
#  'Gemini Man',
#  'Yoga Hosers',
#  'Resident Evil: Retribution',
#  'Les vampires',
#  "The Devil's Own",
#  'Vampires',
#  'Timeline',
#  'No Escape',
#  'Lethal Weapon 2',
#  'The Last Boy Scout',
#  'How It Ends',
#  'Patriot Games',
#  'The American',
#  'Enter the Dragon',
#  'Domino',
#  'Red Sonja',
#  'The Great Wall',
#  'The Beastmaster',
#  'The Poseidon Adventure',
#  'Colombiana',
#  'Seventh Son',
#  'The Rhythm Section',
#  'Cold Pursuit',
#  'The Tax Collector',
#  'Mr. Right',
#  'The Core',
#  'Morgan',
#  'Resident Evil: Extinction',
#  'The Mother',
#  'The Edge',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Need for Speed',
#  'Jane Got a Gun',
#  'The Spiderwick Chronicles',
#  'Destroyer',
#  'The Forbidden Kingdom',
#  'The 6th Day',
#  'National Treasure: Book of Secrets',
#  'Cowboys & Aliens',
#  'Underworld: Blood Wars',
#  ...]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24402 entries, 0 to 24401
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   movie title  24402 non-null  object
#  1   Run Time     24402 non-null  object
#  2   Rating       24402 non-null  float64
#  3   User Rating  24402 non-null  object
#  4   Generes      24402 non-null  object
#  5   Overview     24402 non-null  object
#  6   Director     24402 non-null  object
#  7   Writer       24402 non-null  object
#  8   year         24402 non-null  object
#  9   path         24402 non-null  object
#  10  Keywords     22706 non-null  object
#  11  Stars        24401 non-null  object
#  12  text         24402 non-null  object
#  13  length_text  24402 non-null  int64
#  14  embeddings   24402 non-null  object
#  15  ids          24402 non-null  int64
# dtypes: float64(1), int64(2), object(13)
# memory usage: 3.0+ MB

# %%
df.sample(3)
# Out:
#                 movie title           Run Time  Rating User Rating  \
# 13981        The Supergrass       not-released     6.3         611
# 3835             Superchick       not-released     3.7         575
# 18756  She's Out of Control  1 hour 30 minutes     5.3        4.4K
#
#                     Generes  \
# 13981   ['Comedy', 'Crime']
# 3835   ['Action', 'Comedy']
# 18756            ['Comedy']
#
#                                                 Overview          Director  \
# 13981  While taking a holiday in the country with his...  Peter Richardson
# 3835   Tara B. True is a flight attendant who makes a...        Ed Forsyth
# 18756  When an average-looking teenage girl gets a ma...      Stan Dragoti
#
#                  Writer   year               path  \
# 13981  Peter Richardson  -1985  /title/tt0090102/
# 3835      Gary Crutcher  -1973  /title/tt0070752/
# 18756      Seth Winston  -1989  /title/tt0098308/
#
#                                                 Keywords  \
# 13981  female nudity vomiting alternative comedy male...
# 3835   grindhouse film sex in a bathroom erotic 70s f...
# 18756  makeover teenage girl beach paranoia therapist...
#
#                                                    Stars  \
# 13981  Pete Richens Adrian Edmondson Jennifer Saunder...
# 3835   John H. Burrows Joyce Jillson Louis Quinn Thom...
# 18756  Michael J. Nathanson Tony Danza Catherine Hick...
#
#                                                     text  length_text  \
# 13981  While taking a holiday in the country with his...          509
# 3835   Tara B. True is a flight attendant who makes a...          521
# 18756  When an average-looking teenage girl gets a ma...          333
#
#                                               embeddings    ids
# 13981  [-0.05452210456132889, 0.054123055189847946, -...  13981
# 3835   [-0.06153341010212898, -0.0787108764052391, -0...   3835
# 18756  [-0.07038451731204987, -0.006437822710722685, ...  18756

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ## Indice chroma

# %%
import chromadb
from chromadb.utils import embedding_functions

# %%
df_sub = df.iloc[0:5461]
df_sub.shape

# %%
sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name = 'all-MiniLM-L6-v2')

chroma_client = chromadb.Client()
client_persistent = chromadb.PersistentClient(path=path+'index/data_embeddings_movie')
db = client_persistent.create_collection(name='movies_db', embedding_function=sentence_transformer_ef)

# %%
db.add(
    ids=df_sub['ids'].tolist(),
    embeddings=df_sub['embeddings'].tolist(),
    metadatas= df_sub[['movie title', 'Stars']].to_dict('records')
)

# %%
client_persistent_2 = chromadb.PersistentClient(path=path+'index/data_embeddings_movie')

# %%
db_2 = client_persistent_2.get_collection('movies_db')
